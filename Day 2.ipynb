# %%
# Shortcuts

# %% [markdown]
# # Python Introduction

# %% [markdown]
# ![image.png](attachment:4ccf9f3c-f6d8-4fbd-b88e-41613a3eb514.png)

# %% [markdown]
# - Python is a high-level, interpreted, object-oriented programming language known for its readability and ease of use. It was created by Guido van `Rossum and first released in 1991`.
# Key characteristics of Python include:
# - Interpreted:
# Python code is executed line by line by an interpreter, eliminating the need for a separate compilation step. This speeds up the development process.
# - **`High-level`**:
# Python abstracts away many low-level details of computer hardware, allowing developers to focus on problem-solving rather than managing memory or other complex operations.
# - Object-oriented:
# Python supports object-oriented programming (OOP) paradigms, allowing for code organization and reusability through concepts like classes and objects.

# %% [markdown]
# # Title 1
# ## Title 1
# ### Title 1
# #### Title 1
# ##### Title 1
# ##### Title 1
# ######## Title 1

# %% [markdown]
# ### What is Python

# %%
print(a)
# Out:
# 56

# %%
print('hello')

print(12345)

print('Hello world 123')

print('lucky')

print('Aman')
# Out:
# hello
# 12345
# Hello world 123
# lucky
# Aman

# %%
# data containers: data types

# %%
56
# Out:
# 56

# %%
56
# Out:
# 56

# %%
56
# Out:
# 56

# %%
a = 56

# %%
id(56)
# Out:
# 140732187750552

# %%
print(a)
# Out:
# 678

# %%
a = 678

# %%
print(a)
# Out:
# 678

# %%
id(678)
# Out:
# 1721669779664

# %%
id(a)
# Out:
# 1721669781648

# %%
a = 45

# %%
print(a)
# Out:
# 45

# %%
id(a)
# Out:
# 140732187750200

# %%
b = 45

# %%
print(a)
# Out:
# 45

# %%
print(b)
# Out:
# 45

# %%
id(a)
# Out:
# 140732187750200

# %%
id(b)
# Out:
# 140732187750200

# %%
# memory location management

# %%
a = 25.0
b = 25.0
c = 25.00
d = 25.000

# %%
id(a),id(b),id(c),id(d)
# Out:
# (1721623471120, 1721651654736, 1721669783952, 1721669782768)

# %%
id(a)
# Out:
# 1721669782896

# %%
id(b)
# Out:
# 1721669779568

# %%
2**8
# Out:
# 256

# %%
name = 'dhruv'
name2 = 'dHruv'

# %%
id(name)
# Out:
# 1721669694640

# %%
id(name2)
# Out:
# 1721669506496

# %%
a = 45

# %%
Print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 Print(a)
#
# NameError: name 'Print' is not defined

# %%
# declare @name varchar(100) = 'Mohan'

# %%
str name = 'Komal'
# Out:
#   Cell In[180], line 1
#     str name = 'Komal'
#         ^
# SyntaxError: invalid syntax

# %%
name = 34.6

# %%
type(name)
# Out:
# float

# %%
# dynamic symentix

# %%
name = 37
name
# Out:
# 37

# %%
type(name)
# Out:
# int

# %%
# Putin Speech convert

# %%
print('Hello')
print('Python is Awesome')
print(x)
print('Python is very popular')
# Out:
# Hello
# Python is Awesome
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[206], line 3
#       1 print('Hello')
#       2 print('Python is Awesome')
# ----> 3 print(x)
#       4 print('Python is very popular')
#
# NameError: name 'x' is not defined

# %%
# compiled

# %%
# number
# int, float, complex

# %%
a = 45
print(a,type(a))
# Out:
# 45 <class 'int'>

# %%
a = 45.6
print(a,type(a))
# Out:
# 45.6 <class 'float'>

# %%
a = 45 - 8j
print(a,type(a))
# Out:
# (45-8j) <class 'complex'>

# %%
# textual data
 # string: str

# %%
a = 'My name is verma'
print(a,type(a))
# Out:
# My name is verma <class 'str'>

# %%
# collections>> tuple, list

# %%
a = 45,78.8, 'Mohan', 67-8j
print(a)
# Out:
# (45, 78.8, 'Mohan', (67-8j))

# %%
a = (45,78.8, 'Mohan', 67-8j)
print(a)
# Out:
# (45, 78.8, 'Mohan', (67-8j))

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
# list

# %%
a = [45,78.8, 'Mohan', 67-8j]
print(a)
# Out:
# [45, 78.8, 'Mohan', (67-8j)]

# %%
print(type(a))
# Out:
# <class 'list'>
